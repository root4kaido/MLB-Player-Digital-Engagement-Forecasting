# %%
import gc
import os
import sys
import math
import random
import warnings
from pathlib import Path
from joblib import Parallel, delayed
from statsmodels.tsa.deterministic import (CalendarFourier,
                                           CalendarSeasonality,
                                           CalendarTimeTrend,
                                           DeterministicProcess)

from tqdm import tqdm
import os
import ipywidgets as widgets
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pandarallel import pandarallel
pandarallel.initialize()
warnings.simplefilter("ignore")
import ctypes as ct
# Out:
# INFO: Pandarallel will run on 16 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
sys.path.append('../../')
import src.utils as utils

# %%
DATA_DIR = Path("/home/knikaido/work/MLB-Player-Digital-Engagement-Forecasting/data/")
MAIN_DATA_DIR = DATA_DIR / 'mlb-player-digital-engagement-forecasting-update'
OUTPUT_DIR = Path('./output/')

# %%
# Helper function to unpack json found in daily data
def unpack_json(json_str):
    return pd.DataFrame() if pd.isna(json_str) else pd.read_json(json_str)


def unpack_data(data, dfs=None, n_jobs=-1):
    if dfs is not None:
        data = data.loc[:, dfs]
    unnested_dfs = {}
    for name, column in data.iteritems():
        daily_dfs = Parallel(n_jobs=n_jobs)(
            delayed(unpack_json)(item) for date, item in column.iteritems())
        df = pd.concat(daily_dfs)
        unnested_dfs[name] = df
    return unnested_dfs

# %%
def exshow(col,n):
    tmp = training[col]
    tmp = tmp.dropna()
    tmpdf = unpack_json(tmp.iloc[n])
    print(tmpdf.columns)
    return tmpdf

# %%
training = pd.read_csv(MAIN_DATA_DIR / "train_updated.csv")
training
# Out:
#           date                            nextDayPlayerEngagement  \
# 0     20180101  [{"engagementMetricsDate":"2018-01-02","player...
# 1     20180102  [{"engagementMetricsDate":"2018-01-03","player...
# 2     20180103  [{"engagementMetricsDate":"2018-01-04","player...
# 3     20180104  [{"engagementMetricsDate":"2018-01-05","player...
# 4     20180105  [{"engagementMetricsDate":"2018-01-06","player...
# ...        ...                                                ...
# 1289  20210713  [{"engagementMetricsDate":"2021-07-14","player...
# 1290  20210714  [{"engagementMetricsDate":"2021-07-15","player...
# 1291  20210715  [{"engagementMetricsDate":"2021-07-16","player...
# 1292  20210716  [{"engagementMetricsDate":"2021-07-17","player...
# 1293  20210717  [{"engagementMetricsDate":"2021-07-18","player...
#
#                                                   games  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289  [{"gamePk":634675,"gameType":"A","season":2021...
# 1290                                                NaN
# 1291  [{"gamePk":633291,"gameType":"R","season":2021...
# 1292  [{"gamePk":633283,"gameType":"R","season":2021...
# 1293  [{"gamePk":633267,"gameType":"R","season":2021...
#
#                                                 rosters  \
# 0     [{"playerId":400121,"gameDate":"2018-01-01","t...
# 1     [{"playerId":134181,"gameDate":"2018-01-02","t...
# 2     [{"playerId":425492,"gameDate":"2018-01-03","t...
# 3     [{"playerId":282332,"gameDate":"2018-01-04","t...
# 4     [{"playerId":282332,"gameDate":"2018-01-05","t...
# ...                                                 ...
# 1289  [{"playerId":450203,"gameDate":"2021-07-13","t...
# 1290  [{"playerId":444489,"gameDate":"2021-07-14","t...
# 1291  [{"playerId":444489,"gameDate":"2021-07-15","t...
# 1292  [{"playerId":448179,"gameDate":"2021-07-16","t...
# 1293  [{"playerId":445926,"gameDate":"2021-07-17","t...
#
#                                         playerBoxScores  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289  [{"home":0,"gamePk":634675,"gameDate":"2021-07...
# 1290                                                NaN
# 1291                                                NaN
# 1292  [{"home":0,"gamePk":633266,"gameDate":"2021-07...
# 1293                                                NaN
#
#                                           teamBoxScores  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289  [{"home":0,"teamId":159,"gamePk":634675,"gameD...
# 1290                                                NaN
# 1291                                                NaN
# 1292  [{"home":0,"teamId":146,"gamePk":633447,"gameD...
# 1293                                                NaN
#
#                                            transactions  \
# 0     [{"transactionId":340732,"playerId":547348,"pl...
# 1     [{"transactionId":339458,"playerId":621173,"pl...
# 2     [{"transactionId":347527,"playerId":572389,"pl...
# 3     [{"transactionId":339549,"playerId":545343,"pl...
# 4     [{"transactionId":341195,"playerId":628336,"pl...
# ...                                                 ...
# 1289  [{"transactionId":504703,"playerId":573062,"pl...
# 1290  [{"transactionId":504772,"playerId":605347,"pl...
# 1291  [{"transactionId":504997,"playerId":520980,"pl...
# 1292  [{"transactionId":505213,"playerId":621043,"pl...
# 1293  [{"transactionId":505466,"playerId":595928,"pl...
#
#                                               standings  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289  [{"season":2021,"gameDate":"2021-07-13","divis...
# 1290  [{"season":2021,"gameDate":"2021-07-14","divis...
# 1291  [{"season":2021,"gameDate":"2021-07-15","divis...
# 1292  [{"season":2021,"gameDate":"2021-07-16","divis...
# 1293  [{"season":2021,"gameDate":"2021-07-17","divis...
#
#                                                  awards  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289  [{"awardId":"ASMVP","awardName":"All-Star MVP"...
# 1290                                                NaN
# 1291                                                NaN
# 1292                                                NaN
# 1293                                                NaN
#
#                                                  events  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289                                                NaN
# 1290                                                NaN
# 1291                                                NaN
# 1292  [{"gamePk":633346,"gameDate":"2021-07-16","gam...
# 1293                                                NaN
#
#                                  playerTwitterFollowers  \
# 0     [{"date":"2018-01-01","playerId":545361,"playe...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289                                                NaN
# 1290                                                NaN
# 1291                                                NaN
# 1292                                                NaN
# 1293                                                NaN
#
#                                    teamTwitterFollowers
# 0     [{"date":"2018-01-01","teamId":147,"teamName":...
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1289                                                NaN
# 1290                                                NaN
# 1291                                                NaN
# 1292                                                NaN
# 1293                                                NaN
#
# [1294 rows x 12 columns]

# %%
# training['date'] = pd.to_datetime(training['date'], format="%Y%m%d")

# %%
training.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1294 entries, 0 to 1293
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date                     1294 non-null   int64
#  1   nextDayPlayerEngagement  1294 non-null   object
#  2   games                    715 non-null    object
#  3   rosters                  1293 non-null   object
#  4   playerBoxScores          612 non-null    object
#  5   teamBoxScores            612 non-null    object
#  6   transactions             1180 non-null   object
#  7   standings                609 non-null    object
#  8   awards                   309 non-null    object
#  9   events                   609 non-null    object
#  10  playerTwitterFollowers   43 non-null     object
#  11  teamTwitterFollowers     43 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 121.4+ KB

# %%
null = np.nan
true = True
false = False

for col in tqdm(training.columns):

    if col == 'date': continue

    _index = training[col].notnull()
    training.loc[_index, col] = training.loc[_index, col].parallel_apply(lambda x: eval(x))

    outputs = []
    for index, date, record in training.loc[_index, ['date', col]].itertuples():
        _df = pd.DataFrame(record)
        _df['index'] = index
        _df['date'] = date
        outputs.append(_df)

    outputs = pd.concat(outputs).reset_index(drop=True)
    outputs.to_csv(MAIN_DATA_DIR / f'train/{col}_train.csv', index=False)
# Out:
# 100%|██████████| 12/12 [03:43<00:00, 18.63s/it]

# %%
outputs
# Out:
#           date  teamId             teamName          accountName  \
# 0     20180101     147     New York Yankees     New York Yankees
# 1     20180101     112         Chicago Cubs         Chicago Cubs
# 2     20180101     141    Toronto Blue Jays    Toronto Blue Jays
# 3     20180101     111       Boston Red Sox       Boston Red Sox
# 4     20180101     119  Los Angeles Dodgers  Los Angeles Dodgers
# ...        ...     ...                  ...                  ...
# 1285  20210701     115     Colorado Rockies     Colorado Rockies
# 1286  20210701     136     Seattle Mariners     Seattle Mariners
# 1287  20210701     133    Oakland Athletics    Oakland Athletics
# 1288  20210701     135     San Diego Padres     San Diego Padres
# 1289  20210701     146        Miami Marlins        Miami Marlins
#
#      twitterHandle  numberOfFollowers  index
# 0         @Yankees            3130482      0
# 1            @Cubs            2373710      0
# 2        @BlueJays            2196352      0
# 3          @RedSox            1950737      0
# 4         @Dodgers            1949542      0
# ...            ...                ...    ...
# 1285      @Rockies             588362   1277
# 1286     @Mariners             580268   1277
# 1287    @Athletics             579369   1277
# 1288       @Padres             497594   1277
# 1289      @Marlins             369838   1277
#
# [1290 rows x 7 columns]

# %% [markdown]
# ## テストで取ってこれる一行はこんな感じ

# %%
example_sample_submission = pd.read_csv(MAIN_DATA_DIR / "example_sample_submission.csv")
example_sample_submission

# %%
example_test = pd.read_csv(MAIN_DATA_DIR / "example_test.csv")
example_test
# Out:
#        date                                              games  \
# 0  20210426  [{"gamePk":634374,"gameType":"R","season":2021...
# 1  20210427  [{"gamePk":634318,"gameType":"R","season":2021...
# 2  20210428  [{"gamePk":634309,"gameType":"R","season":2021...
# 3  20210429  [{"gamePk":634330,"gameType":"R","season":2021...
# 4  20210430  [{"gamePk":634287,"gameType":"R","season":2021...
#
#                                              rosters  \
# 0  [{"playerId":405395,"gameDate":"2021-04-26","t...
# 1  [{"playerId":443558,"gameDate":"2021-04-27","t...
# 2  [{"playerId":429722,"gameDate":"2021-04-28","t...
# 3  [{"playerId":405395,"gameDate":"2021-04-29","t...
# 4  [{"playerId":405395,"gameDate":"2021-04-30","t...
#
#                                      playerBoxScores  \
# 0  [{"home":1,"gamePk":634377,"gameDate":"2021-04...
# 1  [{"home":1,"gamePk":634320,"gameDate":"2021-04...
# 2  [{"home":1,"gamePk":634310,"gameDate":"2021-04...
# 3  [{"home":1,"gamePk":634330,"gameDate":"2021-04...
# 4  [{"home":1,"gamePk":634305,"gameDate":"2021-04...
#
#                                        teamBoxScores  \
# 0  [{"home":1,"teamId":139,"gamePk":634343,"gameD...
# 1  [{"home":1,"teamId":117,"gamePk":634333,"gameD...
# 2  [{"home":0,"teamId":111,"gamePk":634310,"gameD...
# 3  [{"home":0,"teamId":119,"gamePk":634346,"gameD...
# 4  [{"home":1,"teamId":135,"gamePk":634303,"gameD...
#
#                                         transactions  \
# 0  [{"transactionId":480386,"playerId":543685,"pl...
# 1  [{"transactionId":480456,"playerId":642162,"pl...
# 2  [{"transactionId":480728,"playerId":545358,"pl...
# 3  [{"transactionId":480993,"playerId":606965,"pl...
# 4                                                NaN
#
#                                            standings  \
# 0  [{"season":2021,"gameDate":"2021-04-26","divis...
# 1  [{"season":2021,"gameDate":"2021-04-27","divis...
# 2  [{"season":2021,"gameDate":"2021-04-28","divis...
# 3  [{"season":2021,"gameDate":"2021-04-29","divis...
# 4  [{"season":2021,"gameDate":"2021-04-30","divis...
#
#                                               awards  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [{"awardId":"NLRRELMON","awardName":"NL Reliev...
#
#                                               events  playerTwitterFollowers  \
# 0  [{"gamePk":634433,"gameDate":"2021-04-26","gam...                     NaN
# 1  [{"gamePk":634332,"gameDate":"2021-04-27","gam...                     NaN
# 2  [{"gamePk":634317,"gameDate":"2021-04-28","gam...                     NaN
# 3  [{"gamePk":634346,"gameDate":"2021-04-29","gam...                     NaN
# 4  [{"gamePk":634327,"gameDate":"2021-04-30","gam...                     NaN
#
#    teamTwitterFollowers
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN

# %%
test_df = example_test.set_index('date').iloc[:1]

# %%
test_df
# Out:
#                                                       games  \
# date
# 20210426  [{'gamePk': 634374, 'gameType': 'R', 'season':...
#
#                                                     rosters  \
# date
# 20210426  [{"playerId":405395,"gameDate":"2021-04-26","t...
#
#                                             playerBoxScores  \
# date
# 20210426  [{"home":1,"gamePk":634377,"gameDate":"2021-04...
#
#                                               teamBoxScores  \
# date
# 20210426  [{"home":1,"teamId":139,"gamePk":634343,"gameD...
#
#                                                transactions  \
# date
# 20210426  [{"transactionId":480386,"playerId":543685,"pl...
#
#                                                   standings awards  \
# date
# 20210426  [{"season":2021,"gameDate":"2021-04-26","divis...    NaN
#
#                                                      events  \
# date
# 20210426  [{"gamePk":634433,"gameDate":"2021-04-26","gam...
#
#           playerTwitterFollowers  teamTwitterFollowers
# date
# 20210426                     NaN                   NaN

# %%
sample_prediction_df = example_sample_submission[example_sample_submission['date']==test_df.index[0]].set_index('date')

# %%
sample_prediction_df
# Out:
#             date_playerId  target1  target2  target3  target4
# date
# 20210426  20210427_656669        0        0        0        0
# 20210426  20210427_543475        0        0        0        0
# 20210426  20210427_592866        0        0        0        0
# 20210426  20210427_452678        0        0        0        0
# 20210426  20210427_570257        0        0        0        0
# ...                   ...      ...      ...      ...      ...
# 20210426  20210427_593590        0        0        0        0
# 20210426  20210427_642180        0        0        0        0
# 20210426  20210427_663399        0        0        0        0
# 20210426  20210427_664199        0        0        0        0
# 20210426  20210427_595453        0        0        0        0
#
# [1187 rows x 5 columns]
